# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import json
import time

# Import the requests library.
import requests

# Import the datetime module from the datetime library
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(-90,90,size=2000)
lngs=np.random.uniform(-180,180,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates=list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d585405145fe20ac8f4a8b10a20b4c9c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count +=1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        #"Current Description": city_description
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | ushuaia
# Processing Record 2 of Set 16 | hofn
# Processing Record 3 of Set 16 | thompson
# Processing Record 4 of Set 16 | sorong
# Processing Record 5 of Set 16 | mar del plata
# Processing Record 6 of Set 16 | norilsk
# Processing Record 7 of Set 16 | vanimo
# Processing Record 8 of Set 16 | new norfolk
# Processing Record 9 of Set 16 | komsomolskiy
# Processing Record 10 of Set 16 | luderitz
# Processing Record 11 of Set 16 | olinda
# Processing Record 12 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 16 | antofagasta
# Processing Record 14 of Set 16 | lydenburg
# Processing Record 15 of Set 16 | vao
# Processing Record 16 of Set 16 | avarua
# Processing Record 17 of Set 16 | erzurum
# Processing Record 18 of Set 16 | torbay
# Processing Record 19 of Set 16 | canete
# Processing Record 20 of Set 16 | hermanus
# Processing Record 21 of Set 16 | pirmasens
# Processing Record 22 of Set 16 | naryan-mar
# Processing Record 23 of Set 16 | hithadhoo
# Processing Record 24 of Set 16 | morgan city
# Processing Record 25 of Set 16 | dvorichna
# Processing Record 26 of Set 16 | aykhal
# Processing Record 27 of Set 16 | rikitea
# Processing Record 28 of Set 16 | albany
# Processing Record 29 of Set 16 | mataura
# Processing Record 30 of Set 16 | khovu-aksy
# Processing Record 31 of Set 16 | kamenka
# Processing Record 32 of Set 16 | kalemie
# Processing Record 33 of Set 16 | guarapari
# Processing Record 34 of Set 16 | busselton
# Processing Record 35 of Set 16 | bluff
# Processing Record 36 of Set 16 | tasiilaq
# Processing Record 37 of Set 16 | puerto baquerizo moreno
# Processing Record 38 of Set 16 | dongying
# Processing Record 39 of Set 16 | mehamn
# Processing Record 40 of Set 16 | airai
# Processing Record 41 of Set 16 | pandaria
# Processing Record 42 of Set 16 | cape town
# Processing Record 43 of Set 16 | ibb
# Processing Record 44 of Set 16 | kalmunai
# Processing Record 45 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 16 | ormara
# Processing Record 47 of Set 16 | walvis bay
# Processing Record 48 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 16 | upernavik
# Processing Record 50 of Set 16 | inhambane
# Processing Record 1 of Set 17 | lebu
# Processing Record 2 of Set 17 | eyl
# Processing Record 3 of Set 17 | los llanos de aridane
# Processing Record 4 of Set 17 | atuona
# Processing Record 5 of Set 17 | port elizabeth
# Processing Record 6 of Set 17 | presidencia roque saenz pena
# Processing Record 7 of Set 17 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 17 | biak
# Processing Record 9 of Set 17 | port alfred
# Processing Record 10 of Set 17 | murud
# Processing Record 11 of Set 17 | solnechnyy
# Processing Record 12 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 17 | north bend
# Processing Record 14 of Set 17 | kloulklubed
# Processing Record 15 of Set 17 | punta arenas
# Processing Record 16 of Set 17 | yellowknife
# Processing Record 17 of Set 17 | southbridge
# Processing Record 18 of Set 17 | castro
# Processing Record 19 of Set 17 | vila
# Processing Record 20 of Set 17 | howard springs
# Processing Record 21 of Set 17 | port macquarie
# Processing Record 22 of Set 17 | forte dei marmi
# Processing Record 23 of Set 17 | kundiawa
# Processing Record 24 of Set 17 | loanda
# Processing Record 25 of Set 17 | hilo
# Processing Record 26 of Set 17 | lorengau
# Processing Record 27 of Set 17 | namibe
# Processing Record 28 of Set 17 | port maria
# Processing Record 29 of Set 17 | berdigestyakh
# Processing Record 30 of Set 17 | provideniya
# Processing Record 31 of Set 17 | oneida
# Processing Record 32 of Set 17 | jamestown
# Processing Record 33 of Set 17 | mumbwa
# Processing Record 34 of Set 17 | diffa
# Processing Record 35 of Set 17 | bethel
# Processing Record 36 of Set 17 | bredasdorp
# Processing Record 37 of Set 17 | milingimbi
# City not found. Skipping...
# Processing Record 38 of Set 17 | college
# Processing Record 39 of Set 17 | urma
# Processing Record 40 of Set 17 | fairbanks
# Processing Record 41 of Set 17 | basco
# Processing Record 42 of Set 17 | cherskiy
# Processing Record 43 of Set 17 | tuktoyaktuk
# Processing Record 44 of Set 17 | barrow
# Processing Record 45 of Set 17 | butaritari
# Processing Record 46 of Set 17 | puro
# Processing Record 47 of Set 17 | puerto ayora
# Processing Record 48 of Set 17 | kapaa
# Processing Record 49 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 17 | fort nelson
# Processing Record 1 of Set 18 | rio grande
# Processing Record 2 of Set 18 | yanchukan
# City not found. Skipping...
# Processing Record 3 of Set 18 | georgetown
# Processing Record 4 of Set 18 | surgut
# Processing Record 5 of Set 18 | durban
# Processing Record 6 of Set 18 | tateyama
# Processing Record 7 of Set 18 | bilibino
# Processing Record 8 of Set 18 | tiarei
# Processing Record 9 of Set 18 | kiama
# Processing Record 10 of Set 18 | broome
# Processing Record 11 of Set 18 | dingle
# Processing Record 12 of Set 18 | kodiak
# Processing Record 13 of Set 18 | severo-kurilsk
# Processing Record 14 of Set 18 | abdanan
# Processing Record 15 of Set 18 | mastic beach
# Processing Record 16 of Set 18 | pinega
# Processing Record 17 of Set 18 | victor harbor
# Processing Record 18 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 18 | troitsko-pechorsk
# Processing Record 20 of Set 18 | sicamous
# Processing Record 21 of Set 18 | aksarka
# Processing Record 22 of Set 18 | portland
# Processing Record 23 of Set 18 | mecca
# Processing Record 24 of Set 18 | maple creek
# Processing Record 25 of Set 18 | rio gallegos
# Processing Record 26 of Set 18 | chokurdakh
# Processing Record 27 of Set 18 | pudozh
# Processing Record 28 of Set 18 | vaini
# Processing Record 29 of Set 18 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 18 | east london
# Processing Record 31 of Set 18 | souillac
# Processing Record 32 of Set 18 | sakakah
# Processing Record 33 of Set 18 | qaanaaq
# Processing Record 34 of Set 18 | tiksi
# Processing Record 35 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 18 | hasaki
# Processing Record 37 of Set 18 | santa vitoria
# Processing Record 38 of Set 18 | zyryanovsk
# Processing Record 39 of Set 18 | lata
# Processing Record 40 of Set 18 | hami
# Processing Record 41 of Set 18 | te anau
# Processing Record 42 of Set 18 | vila velha
# Processing Record 43 of Set 18 | port blair
# Processing Record 44 of Set 18 | bud
# Processing Record 45 of Set 18 | saint anthony
# Processing Record 46 of Set 18 | dikson
# Processing Record 47 of Set 18 | beloha
# Processing Record 48 of Set 18 | palu
# Processing Record 49 of Set 18 | hobart
# Processing Record 50 of Set 18 | dawson creek
# Processing Record 1 of Set 19 | ponta do sol
# Processing Record 2 of Set 19 | bousso
# Processing Record 3 of Set 19 | pevek
# Processing Record 4 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 19 | muros
# Processing Record 6 of Set 19 | jumla
# Processing Record 7 of Set 19 | taltal
# Processing Record 8 of Set 19 | colares
# Processing Record 9 of Set 19 | tigre
# Processing Record 10 of Set 19 | labuan
# Processing Record 11 of Set 19 | surt
# Processing Record 12 of Set 19 | zhigansk
# Processing Record 13 of Set 19 | mount gambier
# Processing Record 14 of Set 19 | yarada
# Processing Record 15 of Set 19 | darhan
# Processing Record 16 of Set 19 | atambua
# Processing Record 17 of Set 19 | road town
# Processing Record 18 of Set 19 | saldanha
# Processing Record 19 of Set 19 | maragogi
# Processing Record 20 of Set 19 | manggar
# Processing Record 21 of Set 19 | barvinkove
# Processing Record 22 of Set 19 | jiaonan
# Processing Record 23 of Set 19 | mandla
# Processing Record 24 of Set 19 | altamira
# Processing Record 25 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 19 | mahebourg
# Processing Record 27 of Set 19 | sakharovo
# Processing Record 28 of Set 19 | ye
# City not found. Skipping...
# Processing Record 29 of Set 19 | codrington
# Processing Record 30 of Set 19 | the valley
# Processing Record 31 of Set 19 | keti bandar
# Processing Record 32 of Set 19 | lebanon
# Processing Record 33 of Set 19 | ribeira grande
# Processing Record 34 of Set 19 | ambilobe
# Processing Record 35 of Set 19 | ugoofaaru
# Processing Record 36 of Set 19 | marsabit
# Processing Record 37 of Set 19 | santiago del estero
# Processing Record 38 of Set 19 | luanda
# Processing Record 39 of Set 19 | faanui
# Processing Record 40 of Set 19 | touros
# Processing Record 41 of Set 19 | beidao
# Processing Record 42 of Set 19 | beisfjord
# Processing Record 43 of Set 19 | vryburg
# Processing Record 44 of Set 19 | esperance
# Processing Record 45 of Set 19 | hay river
# Processing Record 46 of Set 19 | longyearbyen
# Processing Record 47 of Set 19 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 19 | upata
# Processing Record 49 of Set 19 | cabo san lucas
# Processing Record 50 of Set 19 | ilulissat
# Processing Record 1 of Set 20 | kerchevskiy
# Processing Record 2 of Set 20 | umm lajj
# Processing Record 3 of Set 20 | gamba
# Processing Record 4 of Set 20 | sabla
# Processing Record 5 of Set 20 | nome
# Processing Record 6 of Set 20 | nikel
# Processing Record 7 of Set 20 | mingaora
# Processing Record 8 of Set 20 | ostrovnoy
# Processing Record 9 of Set 20 | kavieng
# Processing Record 10 of Set 20 | olenegorsk
# Processing Record 11 of Set 20 | severo-yeniseyskiy
# Processing Record 12 of Set 20 | quirinopolis
# Processing Record 13 of Set 20 | male
# Processing Record 14 of Set 20 | da lat
# Processing Record 15 of Set 20 | smithers
# Processing Record 16 of Set 20 | kudahuvadhoo
# Processing Record 17 of Set 20 | vardo
# Processing Record 18 of Set 20 | miraflores
# Processing Record 19 of Set 20 | tessalit
# Processing Record 20 of Set 20 | vagay
# Processing Record 21 of Set 20 | san francisco
# Processing Record 22 of Set 20 | kamaishi
# Processing Record 23 of Set 20 | maungatapere
# Processing Record 24 of Set 20 | arraial do cabo
# Processing Record 25 of Set 20 | stony plain
# Processing Record 26 of Set 20 | paita
# Processing Record 27 of Set 20 | cockburn town
# Processing Record 28 of Set 20 | narsaq
# Processing Record 29 of Set 20 | phonhong
# Processing Record 30 of Set 20 | jiazi
# Processing Record 31 of Set 20 | celendin
# Processing Record 32 of Set 20 | batagay-alyta
# Processing Record 33 of Set 20 | ancud
# Processing Record 34 of Set 20 | cazaje
# City not found. Skipping...
# Processing Record 35 of Set 20 | bayir
# Processing Record 36 of Set 20 | baykit
# Processing Record 37 of Set 20 | jalpan
# Processing Record 38 of Set 20 | dakar
# Processing Record 39 of Set 20 | maracacume
# Processing Record 40 of Set 20 | blagodatnoye
# Processing Record 41 of Set 20 | bengkulu
# Processing Record 42 of Set 20 | bambous virieux
# Processing Record 43 of Set 20 | mogadishu
# Processing Record 44 of Set 20 | prince rupert
# Processing Record 45 of Set 20 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 20 | kirkuk
# Processing Record 47 of Set 20 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 20 | meulaboh
# Processing Record 49 of Set 20 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 20 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 21 | saint-philippe
# Processing Record 2 of Set 21 | lakselv
# Processing Record 3 of Set 21 | comodoro rivadavia
# Processing Record 4 of Set 21 | constitucion
# Processing Record 5 of Set 21 | altay
# Processing Record 6 of Set 21 | new baltimore
# Processing Record 7 of Set 21 | el tigre
# Processing Record 8 of Set 21 | safwah
# City not found. Skipping...
# Processing Record 9 of Set 21 | nantucket
# Processing Record 10 of Set 21 | labuhan
# Processing Record 11 of Set 21 | nha trang
# Processing Record 12 of Set 21 | kaeo
# Processing Record 13 of Set 21 | tromso
# Processing Record 14 of Set 21 | koutsouras
# Processing Record 15 of Set 21 | rudbar
# Processing Record 16 of Set 21 | coquimbo
# Processing Record 17 of Set 21 | salvador
# Processing Record 18 of Set 21 | imbituba
# Processing Record 19 of Set 21 | carnarvon
# Processing Record 20 of Set 21 | port pirie
# Processing Record 21 of Set 21 | norman wells
# Processing Record 22 of Set 21 | okhotsk
# Processing Record 23 of Set 21 | kuji
# Processing Record 24 of Set 21 | saskylakh
# Processing Record 25 of Set 21 | fallon
# Processing Record 26 of Set 21 | le port
# Processing Record 27 of Set 21 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 21 | xai-xai
# Processing Record 29 of Set 21 | dandong
# Processing Record 30 of Set 21 | amambai
# Processing Record 31 of Set 21 | les cayes
# Processing Record 32 of Set 21 | uthal
# Processing Record 33 of Set 21 | hunsur
# Processing Record 34 of Set 21 | denpasar
# Processing Record 35 of Set 21 | awjilah
# Processing Record 36 of Set 21 | darnetal
# Processing Record 37 of Set 21 | matagami
# Processing Record 38 of Set 21 | davidson
# Processing Record 39 of Set 21 | mbanza-ngungu
# Processing Record 40 of Set 21 | raudeberg
# Processing Record 41 of Set 21 | shumskiy
# Processing Record 42 of Set 21 | naica
# Processing Record 43 of Set 21 | gat
# Processing Record 44 of Set 21 | banda aceh
# Processing Record 45 of Set 21 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 21 | chuy
# Processing Record 47 of Set 21 | beyneu
# Processing Record 48 of Set 21 | antalaha
# Processing Record 49 of Set 21 | raga
# Processing Record 50 of Set 21 | idil
# Processing Record 1 of Set 22 | khatanga
# Processing Record 2 of Set 22 | chaihe
# Processing Record 3 of Set 22 | sanming
# Processing Record 4 of Set 22 | mae chan
# Processing Record 5 of Set 22 | riyadh
# Processing Record 6 of Set 22 | san pedro de macoris
# Processing Record 7 of Set 22 | yulara
# Processing Record 8 of Set 22 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 22 | anadyr
# Processing Record 10 of Set 22 | ahipara
# Processing Record 11 of Set 22 | huarmey
# Processing Record 12 of Set 22 | kemin
# Processing Record 13 of Set 22 | uglich
# Processing Record 14 of Set 22 | igarka
# Processing Record 15 of Set 22 | richards bay
# Processing Record 16 of Set 22 | burica
# City not found. Skipping...
# Processing Record 17 of Set 22 | port lincoln
# Processing Record 18 of Set 22 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 22 | tuatapere
# Processing Record 20 of Set 22 | pochutla
# Processing Record 21 of Set 22 | kahului
# Processing Record 22 of Set 22 | port hardy
# Processing Record 23 of Set 22 | acarau
# Processing Record 24 of Set 22 | hengshui
# Processing Record 25 of Set 22 | mbandaka
# Processing Record 26 of Set 22 | klaksvik
# Processing Record 27 of Set 22 | flinders
# Processing Record 28 of Set 22 | worthington
# Processing Record 29 of Set 22 | kropotkin
# Processing Record 30 of Set 22 | pitea
# Processing Record 31 of Set 22 | mahon
# Processing Record 32 of Set 22 | oussouye
# Processing Record 33 of Set 22 | yar-sale
# Processing Record 34 of Set 22 | chenzhou
# Processing Record 35 of Set 22 | khomeyn
# Processing Record 36 of Set 22 | asau
# Processing Record 37 of Set 22 | nikolskoye
# Processing Record 38 of Set 22 | pauini
# Processing Record 39 of Set 22 | geeste
# Processing Record 40 of Set 22 | dunedin
# Processing Record 41 of Set 22 | koudougou
# Processing Record 42 of Set 22 | pacific grove
# Processing Record 43 of Set 22 | lavrentiya
# Processing Record 44 of Set 22 | kieta
# Processing Record 45 of Set 22 | senanga
# Processing Record 46 of Set 22 | la ronge
# Processing Record 47 of Set 22 | san quintin
# Processing Record 48 of Set 22 | mount isa
# Processing Record 49 of Set 22 | ntcheu
# Processing Record 50 of Set 22 | sioux lookout
# Processing Record 1 of Set 23 | victoria
# Processing Record 2 of Set 23 | scarborough
# Processing Record 3 of Set 23 | guerrero negro
# Processing Record 4 of Set 23 | hamilton
# Processing Record 5 of Set 23 | manakara
# Processing Record 6 of Set 23 | hirara
# Processing Record 7 of Set 23 | leningradskiy
# Processing Record 8 of Set 23 | luba
# Processing Record 9 of Set 23 | seminole
# Processing Record 10 of Set 23 | sasaram
# Processing Record 11 of Set 23 | tiradentes
# Processing Record 12 of Set 23 | sunrise manor
# Processing Record 13 of Set 23 | porto walter
# Processing Record 14 of Set 23 | chara
# Processing Record 15 of Set 23 | ryotsu
# Processing Record 16 of Set 23 | cidreira
# Processing Record 17 of Set 23 | ossora
# Processing Record 18 of Set 23 | fortuna
# Processing Record 19 of Set 23 | hakodate
# Processing Record 20 of Set 23 | nanortalik
# Processing Record 21 of Set 23 | lincoln
# Processing Record 22 of Set 23 | dingli
# Processing Record 23 of Set 23 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 23 | zharkent
# Processing Record 25 of Set 23 | ulladulla
# Processing Record 26 of Set 23 | kenai
# Processing Record 27 of Set 23 | beringovskiy
# Processing Record 28 of Set 23 | grand gaube
# Processing Record 29 of Set 23 | kabare
# Processing Record 30 of Set 23 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 23 | gumushane
# City not found. Skipping...
# Processing Record 32 of Set 23 | vanderhoof
# Processing Record 33 of Set 23 | turochak
# Processing Record 34 of Set 23 | ifakara
# Processing Record 35 of Set 23 | peruibe
# Processing Record 36 of Set 23 | agadez
# Processing Record 37 of Set 23 | otradnoye
# Processing Record 38 of Set 23 | coari
# Processing Record 39 of Set 23 | pantai remis
# Processing Record 40 of Set 23 | disna
# Processing Record 41 of Set 23 | wewak
# Processing Record 42 of Set 23 | bohodukhiv
# Processing Record 43 of Set 23 | suicheng
# Processing Record 44 of Set 23 | sao bento do sul
# Processing Record 45 of Set 23 | alofi
# Processing Record 46 of Set 23 | takaungu
# Processing Record 47 of Set 23 | winnemucca
# Processing Record 48 of Set 23 | mutoko
# Processing Record 49 of Set 23 | pangnirtung
# Processing Record 50 of Set 23 | koulikoro
# Processing Record 1 of Set 24 | qui nhon
# Processing Record 2 of Set 24 | uyuni
# Processing Record 3 of Set 24 | beni mazar
# Processing Record 4 of Set 24 | skjervoy
# Processing Record 5 of Set 24 | kattivakkam
# Processing Record 6 of Set 24 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 24 | rastede
# Processing Record 8 of Set 24 | revelstoke
# Processing Record 9 of Set 24 | oranjemund
# Processing Record 10 of Set 24 | soledade
# Processing Record 11 of Set 24 | cap malheureux
# Processing Record 12 of Set 24 | havre-saint-pierre
# Processing Record 13 of Set 24 | mahibadhoo
# Processing Record 14 of Set 24 | saint-pierre
# Processing Record 15 of Set 24 | dwarka
# Processing Record 16 of Set 24 | saint-augustin
# Processing Record 17 of Set 24 | bubaque
# Processing Record 18 of Set 24 | okitipupa
# Processing Record 19 of Set 24 | kozhva
# Processing Record 20 of Set 24 | hastings
# Processing Record 21 of Set 24 | husavik
# Processing Record 22 of Set 24 | kaitangata
# Processing Record 23 of Set 24 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 24 | koumac
# Processing Record 25 of Set 24 | wollongong
# Processing Record 26 of Set 24 | bonthe
# Processing Record 27 of Set 24 | kijang
# Processing Record 28 of Set 24 | cabedelo
# Processing Record 29 of Set 24 | plouzane
# Processing Record 30 of Set 24 | riberalta
# Processing Record 31 of Set 24 | bakchar
# Processing Record 32 of Set 24 | berlevag
# Processing Record 33 of Set 24 | granada
# Processing Record 34 of Set 24 | mago
# Processing Record 35 of Set 24 | shar
# Processing Record 36 of Set 24 | geraldton
# Processing Record 37 of Set 24 | chicama
# Processing Record 38 of Set 24 | kouvaras
# Processing Record 39 of Set 24 | ikalamavony
# Processing Record 40 of Set 24 | leh
# Processing Record 41 of Set 24 | sampit
# Processing Record 42 of Set 24 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 24 | fuyang
# Processing Record 44 of Set 24 | lodwar
# Processing Record 45 of Set 24 | bara
# Processing Record 46 of Set 24 | caravelas
# Processing Record 47 of Set 24 | isangel
# Processing Record 48 of Set 24 | charters towers
# Processing Record 49 of Set 24 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 24 | verkhoshizhemye
# Processing Record 1 of Set 25 | tabora
# Processing Record 2 of Set 25 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 25 | ndele
# Processing Record 4 of Set 25 | gigante
# Processing Record 5 of Set 25 | gibsons
# Processing Record 6 of Set 25 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 25 | palmer
# Processing Record 8 of Set 25 | padang
# Processing Record 9 of Set 25 | point pleasant
# Processing Record 10 of Set 25 | lokosovo
# Processing Record 11 of Set 25 | jaciara
# Processing Record 12 of Set 25 | imeni zhelyabova
# Processing Record 13 of Set 25 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 25 | santa cruz de la palma
# Processing Record 15 of Set 25 | kirakira
# Processing Record 16 of Set 25 | acapulco
# Processing Record 17 of Set 25 | gerardmer
# Processing Record 18 of Set 25 | ambon
# Processing Record 19 of Set 25 | san patricio
# Processing Record 20 of Set 25 | veraval
# Processing Record 21 of Set 25 | valencia
# Processing Record 22 of Set 25 | wageningen
# Processing Record 23 of Set 25 | thinadhoo
# Processing Record 24 of Set 25 | kirov
# Processing Record 25 of Set 25 | ibra
# Processing Record 26 of Set 25 | la baneza
# Processing Record 27 of Set 25 | port hedland
# Processing Record 28 of Set 25 | liwale
# Processing Record 29 of Set 25 | repedea
# Processing Record 30 of Set 25 | lodi
# Processing Record 31 of Set 25 | polunochnoye
# Processing Record 32 of Set 25 | gobabis
# Processing Record 33 of Set 25 | bethanien
# Processing Record 34 of Set 25 | volksrust
# Processing Record 35 of Set 25 | clyde river
# Processing Record 36 of Set 25 | vostok
# Processing Record 37 of Set 25 | liberal
# Processing Record 38 of Set 25 | tupik
# Processing Record 39 of Set 25 | tagusao
# Processing Record 40 of Set 25 | luau
# Processing Record 41 of Set 25 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 25 | xining
# Processing Record 43 of Set 25 | bogotol
# Processing Record 44 of Set 25 | sitka
# Processing Record 45 of Set 25 | cacapava do sul
# Processing Record 46 of Set 25 | santarem
# Processing Record 47 of Set 25 | belaya gora
# Processing Record 48 of Set 25 | uporovo
# Processing Record 49 of Set 25 | bafq
# Processing Record 50 of Set 25 | alanya
# Processing Record 1 of Set 26 | hazorasp
# Processing Record 2 of Set 26 | olafsvik
# Processing Record 3 of Set 26 | sukhodol
# Processing Record 4 of Set 26 | ozimek
# Processing Record 5 of Set 26 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 26 | limoux
# Processing Record 7 of Set 26 | corn island
# Processing Record 8 of Set 26 | sao filipe
# Processing Record 9 of Set 26 | nenjiang
# Processing Record 10 of Set 26 | dharmanagar
# Processing Record 11 of Set 26 | kibre mengist
# Processing Record 12 of Set 26 | esterhazy
# Processing Record 13 of Set 26 | lompoc
# Processing Record 14 of Set 26 | kosh-agach
# Processing Record 15 of Set 26 | manzhouli
# Processing Record 16 of Set 26 | khandyga
# Processing Record 17 of Set 26 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 26 | karratha
# Processing Record 19 of Set 26 | atar
# Processing Record 20 of Set 26 | marilandia
# Processing Record 21 of Set 26 | nago
# Processing Record 22 of Set 26 | saint george
# Processing Record 23 of Set 26 | san javier
# Processing Record 24 of Set 26 | mayo
# Processing Record 25 of Set 26 | ponerihouen
# Processing Record 26 of Set 26 | abha
# Processing Record 27 of Set 26 | soe
# Processing Record 28 of Set 26 | hobyo
# Processing Record 29 of Set 26 | meghri
# Processing Record 30 of Set 26 | mlonggo
# Processing Record 31 of Set 26 | santa catalina
# Processing Record 32 of Set 26 | opobo
# City not found. Skipping...
# Processing Record 33 of Set 26 | laguna
# Processing Record 34 of Set 26 | cotonou
# Processing Record 35 of Set 26 | aktash
# Processing Record 36 of Set 26 | tazovskiy
# Processing Record 37 of Set 26 | solwezi
# Processing Record 38 of Set 26 | griffith
# Processing Record 39 of Set 26 | nemuro
# Processing Record 40 of Set 26 | bendorf
# Processing Record 41 of Set 26 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 26 | akora
# Processing Record 43 of Set 26 | jalu
# Processing Record 44 of Set 26 | valparaiso
# Processing Record 45 of Set 26 | tukrah
# Processing Record 46 of Set 26 | totness
# Processing Record 47 of Set 26 | aklavik
# Processing Record 48 of Set 26 | santa isabel do rio negro
# Processing Record 49 of Set 26 | easley
# Processing Record 50 of Set 26 | talnakh
# Processing Record 1 of Set 27 | makakilo city
# Processing Record 2 of Set 27 | kruisfontein
# Processing Record 3 of Set 27 | guia de isora
# Processing Record 4 of Set 27 | karatau
# Processing Record 5 of Set 27 | makokou
# Processing Record 6 of Set 27 | ust-kuyga
# Processing Record 7 of Set 27 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 27 | labrea
# Processing Record 9 of Set 27 | lasa
# Processing Record 10 of Set 27 | presidente bernardes
# Processing Record 11 of Set 27 | rumoi
# Processing Record 12 of Set 27 | rawson
# Processing Record 13 of Set 27 | kadykchan
# City not found. Skipping...
# Processing Record 14 of Set 27 | aasiaat
# Processing Record 15 of Set 27 | kuzhener
# Processing Record 16 of Set 27 | avezzano
# Processing Record 17 of Set 27 | zambezi
# Processing Record 18 of Set 27 | viet tri
# Processing Record 19 of Set 27 | pundaguitan
# Processing Record 20 of Set 27 | bulgan
# Processing Record 21 of Set 27 | erzin
# Processing Record 22 of Set 27 | wahiawa
# Processing Record 23 of Set 27 | ongandjera
# Processing Record 24 of Set 27 | mantua
# Processing Record 25 of Set 27 | mitu
# Processing Record 26 of Set 27 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 27 | minab
# Processing Record 28 of Set 27 | iquitos
# Processing Record 29 of Set 27 | ucluelet
# Processing Record 30 of Set 27 | chapais
# Processing Record 31 of Set 27 | calbuco
# Processing Record 32 of Set 27 | selma
# Processing Record 33 of Set 27 | haines junction
# Processing Record 34 of Set 27 | palauig
# Processing Record 35 of Set 27 | birin
# Processing Record 36 of Set 27 | makungu
# Processing Record 37 of Set 27 | achisay
# City not found. Skipping...
# Processing Record 38 of Set 27 | soyo
# Processing Record 39 of Set 27 | ystad
# Processing Record 40 of Set 27 | samarai
# Processing Record 41 of Set 27 | belmonte
# Processing Record 42 of Set 27 | tashla
# Processing Record 43 of Set 27 | gulshat
# City not found. Skipping...
# Processing Record 44 of Set 27 | dicabisagan
# Processing Record 45 of Set 27 | mollendo
# Processing Record 46 of Set 27 | juneau
# Processing Record 47 of Set 27 | broken hill
# Processing Record 48 of Set 27 | san cristobal
# Processing Record 49 of Set 27 | gerede
# Processing Record 50 of Set 27 | malatya
# Processing Record 1 of Set 28 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 28 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 28 | calama
# Processing Record 4 of Set 28 | lake city
# Processing Record 5 of Set 28 | doha
# Processing Record 6 of Set 28 | kakonko
# Processing Record 7 of Set 28 | holland
# Processing Record 8 of Set 28 | ghanzi
# Processing Record 9 of Set 28 | nuristan
# Processing Record 10 of Set 28 | gorontalo
# Processing Record 11 of Set 28 | byron bay
# Processing Record 12 of Set 28 | aripuana
# Processing Record 13 of Set 28 | cozumel
# Processing Record 14 of Set 28 | waipawa
# Processing Record 15 of Set 28 | trelew
# Processing Record 16 of Set 28 | yilan
# Processing Record 17 of Set 28 | marawi
# Processing Record 18 of Set 28 | lima
# Processing Record 19 of Set 28 | auki
# Processing Record 20 of Set 28 | gazni
# City not found. Skipping...
# Processing Record 21 of Set 28 | tunduru
# City not found. Skipping...
# Processing Record 22 of Set 28 | puri
# Processing Record 23 of Set 28 | kawalu
# Processing Record 24 of Set 28 | moerai
# Processing Record 25 of Set 28 | texarkana
# Processing Record 26 of Set 28 | narovchat
# Processing Record 27 of Set 28 | batemans bay
# Processing Record 28 of Set 28 | sabaudia
# Processing Record 29 of Set 28 | nanzhang
# Processing Record 30 of Set 28 | xichang
# Processing Record 31 of Set 28 | balykshi
# Processing Record 32 of Set 28 | shimoda
# Processing Record 33 of Set 28 | bitung
# Processing Record 34 of Set 28 | la palma
# Processing Record 35 of Set 28 | bull savanna
# Processing Record 36 of Set 28 | salalah
# Processing Record 37 of Set 28 | suamico
# Processing Record 38 of Set 28 | isabela
# Processing Record 39 of Set 28 | samara
# Processing Record 40 of Set 28 | alice springs
# Processing Record 41 of Set 28 | cabra
# Processing Record 42 of Set 28 | raha
# Processing Record 43 of Set 28 | calderitas
# Processing Record 44 of Set 28 | itacoatiara
# Processing Record 45 of Set 28 | qiongshan
# Processing Record 46 of Set 28 | makubetsu
# Processing Record 47 of Set 28 | aktas
# Processing Record 48 of Set 28 | lodja
# Processing Record 49 of Set 28 | sibolga
# Processing Record 50 of Set 28 | bathsheba
# Processing Record 1 of Set 29 | sedelnikovo
# City not found. Skipping...
# Processing Record 2 of Set 29 | sorland
# Processing Record 3 of Set 29 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 29 | tomigusuku
# Processing Record 5 of Set 29 | baruun-urt
# Processing Record 6 of Set 29 | rocha
# Processing Record 7 of Set 29 | margate
# Processing Record 8 of Set 29 | kirksville
# Processing Record 9 of Set 29 | bozoum
# Processing Record 10 of Set 29 | vanavara
# Processing Record 11 of Set 29 | mangrol
# Processing Record 12 of Set 29 | taoudenni
# Processing Record 13 of Set 29 | dhemaji
# Processing Record 14 of Set 29 | lancut
# Processing Record 15 of Set 29 | esmeraldas
# Processing Record 16 of Set 29 | itapirapua
# Processing Record 17 of Set 29 | maniitsoq
# Processing Record 18 of Set 29 | quepos
# Processing Record 19 of Set 29 | chapada dos guimaraes
# Processing Record 20 of Set 29 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 29 | lafiagi
# Processing Record 22 of Set 29 | ostersund
# Processing Record 23 of Set 29 | puerto del rosario
# Processing Record 24 of Set 29 | yuzhou
# Processing Record 25 of Set 29 | sarkand
# Processing Record 26 of Set 29 | roald
# Processing Record 27 of Set 29 | gornopravdinsk
# Processing Record 28 of Set 29 | pitimbu
# Processing Record 29 of Set 29 | egvekinot
# Processing Record 30 of Set 29 | shingu
# Processing Record 31 of Set 29 | merzifon
# Processing Record 32 of Set 29 | tevriz
# Processing Record 33 of Set 29 | hualmay
# Processing Record 34 of Set 29 | nelson bay
# Processing Record 35 of Set 29 | seymchan
# Processing Record 36 of Set 29 | kourou
# Processing Record 37 of Set 29 | churachandpur
# Processing Record 38 of Set 29 | phan thiet
# Processing Record 39 of Set 29 | hervey bay
# Processing Record 40 of Set 29 | salinas
# Processing Record 41 of Set 29 | high level
# Processing Record 42 of Set 29 | elmira
# Processing Record 43 of Set 29 | pavlovskiy
# Processing Record 44 of Set 29 | eldikan
# City not found. Skipping...
# Processing Record 45 of Set 29 | rudnya
# Processing Record 46 of Set 29 | champasak
# Processing Record 47 of Set 29 | arlit
# Processing Record 48 of Set 29 | bluefield
# Processing Record 49 of Set 29 | gizo
# Processing Record 50 of Set 29 | pregradnaya
# Processing Record 1 of Set 30 | adygeysk
# Processing Record 2 of Set 30 | kochubey
# Processing Record 3 of Set 30 | podporozhye
# Processing Record 4 of Set 30 | tual
# Processing Record 5 of Set 30 | tigil
# Processing Record 6 of Set 30 | hunza
# City not found. Skipping...
# Processing Record 7 of Set 30 | kathmandu
# Processing Record 8 of Set 30 | kachiry
# Processing Record 9 of Set 30 | turan
# Processing Record 10 of Set 30 | fort saint john
# City not found. Skipping...
# Processing Record 11 of Set 30 | huaicheng
# Processing Record 12 of Set 30 | busayra
# Processing Record 13 of Set 30 | nevelsk
# Processing Record 14 of Set 30 | churapcha
# Processing Record 15 of Set 30 | clinton
# Processing Record 16 of Set 30 | bastia
# Processing Record 17 of Set 30 | sohbatpur
# Processing Record 18 of Set 30 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 30 | dali
# Processing Record 20 of Set 30 | mercedes
# Processing Record 21 of Set 30 | salinopolis
# Processing Record 22 of Set 30 | emmett
# Processing Record 23 of Set 30 | daman
# Processing Record 24 of Set 30 | novoagansk
# Processing Record 25 of Set 30 | pedernales
# Processing Record 26 of Set 30 | sfantu gheorghe
# Processing Record 27 of Set 30 | khandagayty
# Processing Record 28 of Set 30 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 30 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 30 | saquarema
# Processing Record 31 of Set 30 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 30 | nhulunbuy
# Processing Record 33 of Set 30 | wanaka
# Processing Record 34 of Set 30 | abu dhabi
# Processing Record 35 of Set 30 | ilawa
# Processing Record 36 of Set 30 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 30 | muriti
# Processing Record 38 of Set 30 | flagstaff
# Processing Record 39 of Set 30 | mandalgovi
# Processing Record 40 of Set 30 | ust-karsk
# Processing Record 41 of Set 30 | pangoa
# Processing Record 42 of Set 30 | henties bay
# Processing Record 43 of Set 30 | bandarbeyla
# Processing Record 44 of Set 30 | sikasso
# Processing Record 45 of Set 30 | iralaya
# Processing Record 46 of Set 30 | willmar
# Processing Record 47 of Set 30 | nuyo
# Processing Record 48 of Set 30 | pakokku
# Processing Record 49 of Set 30 | aleksandrov gay
# Processing Record 50 of Set 30 | burnie
# Processing Record 1 of Set 31 | zyryanka
# Processing Record 2 of Set 31 | bemidji
# Processing Record 3 of Set 31 | staryy nadym
# Processing Record 4 of Set 31 | vestmannaeyjar
# Processing Record 5 of Set 31 | sindor
# Processing Record 6 of Set 31 | russkaya polyana
# Processing Record 7 of Set 31 | arbuzynka
# Processing Record 8 of Set 31 | jaumave
# Processing Record 9 of Set 31 | coihaique
# Processing Record 10 of Set 31 | kawana waters
# City not found. Skipping...
# Processing Record 11 of Set 31 | manuk mangkaw
# Processing Record 12 of Set 31 | novopavlovka
# Processing Record 13 of Set 31 | yerbogachen
# Processing Record 14 of Set 31 | fukue
# Processing Record 15 of Set 31 | buala
# Processing Record 16 of Set 31 | clarence town
# Processing Record 17 of Set 31 | bloomsburg
# Processing Record 18 of Set 31 | chany
# Processing Record 19 of Set 31 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 31 | karpuninskiy
# City not found. Skipping...
# Processing Record 21 of Set 31 | ojinaga
# Processing Record 22 of Set 31 | mudon
# Processing Record 23 of Set 31 | vinh
# Processing Record 24 of Set 31 | fujin
# Processing Record 25 of Set 31 | daltenganj
# Processing Record 26 of Set 31 | baghmara
# Processing Record 27 of Set 31 | somerset
# Processing Record 28 of Set 31 | opuwo
# Processing Record 29 of Set 31 | poum
# Processing Record 30 of Set 31 | buraydah
# Processing Record 31 of Set 31 | lagoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 718

# %%
#Add the data to a list in a dictionary format and then convert the list to a DataFrame.
city_data_df = pd.DataFrame(city_data)


#Reorder columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed","Current Description"]

#assign city_data_df with new column order
city_data_df = city_data_df[new_column_order]

# Display DataFrame
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia      AR -54.8000  -68.3000     60.46        59          75
# 1           Hofn      IS  64.2539  -15.2082     27.00        67           0
# 2       Thompson      CA  55.7435  -97.8558    -11.04        64          20
# 3         Sorong      ID  -0.8833  131.2500     80.29        81         100
# 4  Mar Del Plata      AR -38.0023  -57.5575     66.22        89         100
# 5        Norilsk      RU  69.3535   88.2027    -26.07       100          44
# 6         Vanimo      PG  -2.6741  141.3028     77.63        87         100
# 7    New Norfolk      AU -42.7826  147.0587     52.72        74           4
# 8   Komsomolskiy      UZ  40.4272   71.7189     39.92        87          75
# 9       Luderitz      NA -26.6481   15.1594     68.31        75          11
#
#    Wind Speed Current Description
# 0       17.27       broken clouds
# 1       16.11           clear sky
# 2        4.61          few clouds
# 3       11.25     overcast clouds
# 4       24.00     overcast clouds
# 5        1.54    scattered clouds
# 6        5.12     overcast clouds
# 7        1.95           clear sky
# 8        4.61       broken clouds
# 9        4.70          few clouds

# %%
# Export the DataFrame as a  (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
